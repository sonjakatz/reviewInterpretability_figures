# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import matplotlib.pyplot as plt 


import matplotlib
matplotlib.rcParams.update({'font.size': 15})

sns.set_theme(style="white", palette="pastel", font_scale=1.4)

# %%
data_categories = {'SNPs':"Genomics",
                   'CNV':"Genomics",
                   'CpGs (methylation)':"Epigenetics",
                   'SNV':"Genomics",
                   'mRNA (gene expression)': "Transcriptomics",
                   'miRNA':"Epigenetics",
                   'clinical': "Clinical",
                   'ncRNA':"Epigenetics",
                   'other': "Other",
                   'WES':"Genomics",
                   'ChIP-seq':"Epigenetics",
                   'WGS':"Genomics",
                   'genotype':"Genomics",
                   "Copy number alterations":"Genomics",
                   "Fusions":"Genomics",
                   "Mutations":"Genomics",
                   "sc-transcriptomics":"Transcriptomics",
                   "sc-ATAC":"Epigenetics",
                   "proteome":"Proteomics"}

model_categories = {
    'VAE':"Autoencoder (variational)",
    'VNN (dense)':"Neural network (visible)",
    'AE':"Autoencoder",
    'VAE (conditional)':"Autoencoder (variational & conditional)",
    'Graph Convolutional Network (GCN)':"Graph network (convolutional)",
    'AE (convolutional)':"Autoencoder (convolutional)",
    'LSTM (convolutional)':"LSTM (convolutional)",
    'ensemble (MAE)':"other",
    'fuzzy network':"other",
    'Gaussian-Proces':"other",
    'PCA-like':"other",
    'ANN':"Neural network",
    'VNN (CNN)':"Neural network (visible & convolutional)",
    'AE (vector quantized)':"Autoencoder",
    'AE (stacked)':"Autoencoder (stacked)",
    'VAE (sparse)':"Autoencoder (variational & sparse)",
    'Convolutional Neural Network (CNN)':"Neural network (convolutional)",
    'Dense neural network':"Neural network",
    #'Transformer':"",
    'Capsule Network':"other",
    'Factor Graph Neural Network':"Graph network (factor)",
    'Self-organising maps (SOM)':"other",
    'AE (sparse)':"Autoencoder (sparse)",
    'Graph Network':"Graph network",
    "meta-learning":"other",
    np.nan:""
}

# %%
outPath = "figures"

pd_table1 = pd.read_csv("data/Table_4.csv")

# %%
#@title Models per Datatype


df = pd_table1.copy()
df["Data_type"] = df['Data type'].str.split(', ')
df["Model_architecture"] = df['Model architecture'].str.split(', ')

df = df.explode(["Data_type"])
df = df.explode(["Model_architecture"])


df["Data_type"] = df["Data_type"].values.astype(str)

''' change naming '''
df["Model_architecture"] = df["Model_architecture"].replace(model_categories)
df["Model_architecture"] = df["Model_architecture"].values.astype(str)
df["Data_type"] = df["Data_type"].replace(data_categories)

df = df.sort_values(["Model_architecture"], ascending=True)
df = df[~df["Data type"].isna()]

# %%
### Ploting
fig, ax = plt.subplots(ncols=1, figsize=(12, 10))
sns.histplot(df, x="Data_type", y ="Model_architecture", ax=ax, color="blue", cbar=True,  cbar_kws=dict(shrink=.85))
ax.set_ylabel("")
ax.set_xlabel("")


plt.xticks(rotation=90)


# plt.tight_layout()
# plt.savefig(f"{outPath}/model_dataType.png", dpi=300)
plt.show()

# %%
df = pd_table1.copy()
df["Data_type"] = df['Data type'].str.split(', ')
df["Model_architecture"] = df['Model architecture'].str.split(', ')

df = df.explode(["Data_type"])
df = df.explode(["Model_architecture"])


df["Data_type"] = df["Data_type"].values.astype(str)

''' change naming '''
df["Model_architecture"] = df["Model_architecture"].replace(model_categories)
df["Model_architecture"] = df["Model_architecture"].values.astype(str)
df["Data_type"] = df["Data_type"].replace(data_categories)

df = df.sort_values(["Model_architecture"], ascending=True)
df = df[~df["Data type"].isna()]


x = (df[["Data_type", "Model_architecture"]].value_counts() / df[["Data_type", "Model_architecture"]].value_counts().sum())*100
x = x.unstack().T
x
# Out:
# Data_type                                 Clinical  Epigenetics  Genomics  \
# Model_architecture
# Autoencoder                               0.431034     3.879310  1.724138
# Autoencoder (convolutional)                    NaN          NaN  0.862069
# Autoencoder (sparse)                           NaN          NaN       NaN
# Autoencoder (stacked)                          NaN          NaN  0.431034
# Autoencoder (variational & conditional)        NaN          NaN       NaN
# Autoencoder (variational & sparse)             NaN     0.431034       NaN
# Autoencoder (variational)                 0.431034     2.586207  1.293103
# Generative adversarial network (GAN)      0.431034          NaN  0.431034
# Graph network                                  NaN          NaN       NaN
# Graph network (convolutional)             0.862069     3.017241  3.448276
# Graph network (factor)                         NaN          NaN       NaN
# LSTM                                           NaN     0.431034       NaN
# LSTM (convolutional)                           NaN     0.862069  0.862069
# Neural network                            1.293103     3.017241  6.465517
# Neural network (convolutional)                 NaN     0.862069  1.293103
# Neural network (visible & convolutional)       NaN     0.431034  1.724138
# Neural network (visible)                       NaN     1.293103  8.189655
# Transformer                               0.431034     0.431034  1.724138
# other                                          NaN     0.431034  1.293103
#
# Data_type                                    Other  Proteomics  \
# Model_architecture
# Autoencoder                               0.431034    0.862069
# Autoencoder (convolutional)                    NaN         NaN
# Autoencoder (sparse)                           NaN         NaN
# Autoencoder (stacked)                          NaN         NaN
# Autoencoder (variational & conditional)        NaN         NaN
# Autoencoder (variational & sparse)             NaN         NaN
# Autoencoder (variational)                      NaN    0.431034
# Generative adversarial network (GAN)           NaN         NaN
# Graph network                             0.431034         NaN
# Graph network (convolutional)             0.431034    0.431034
# Graph network (factor)                         NaN         NaN
# LSTM                                           NaN         NaN
# LSTM (convolutional)                           NaN         NaN
# Neural network                            1.293103         NaN
# Neural network (convolutional)            0.431034         NaN
# Neural network (visible & convolutional)  0.431034         NaN
# Neural network (visible)                  0.431034         NaN
# Transformer                                    NaN         NaN
# other                                          NaN         NaN
#
# Data_type                                 Transcriptomics
# Model_architecture
# Autoencoder                                      6.465517
# Autoencoder (convolutional)                           NaN
# Autoencoder (sparse)                             0.862069
# Autoencoder (stacked)                                 NaN
# Autoencoder (variational & conditional)          0.431034
# Autoencoder (variational & sparse)               0.862069
# Autoencoder (variational)                        4.741379
# Generative adversarial network (GAN)                  NaN
# Graph network                                    0.862069
# Graph network (convolutional)                    5.603448
# Graph network (factor)                           0.431034
# LSTM                                                  NaN
# LSTM (convolutional)                                  NaN
# Neural network                                   9.482759
# Neural network (convolutional)                   1.724138
# Neural network (visible & convolutional)         1.724138
# Neural network (visible)                         4.741379
# Transformer                                      2.586207
# other                                            2.586207

# %%
fig, ax = plt.subplots(ncols=1, figsize=(10, 10))
cols = ["Transcriptomics", "Genomics", "Epigenetics", "Clinical", "Proteomics", "Other"]
x = x.loc[:,cols]
sns.heatmap(x, cmap="crest",linewidths=2)
ax.set_ylabel("")
ax.set_xlabel("")
plt.tight_layout()
plt.savefig(f"{outPath}/model_dataType.svg", dpi=300)
