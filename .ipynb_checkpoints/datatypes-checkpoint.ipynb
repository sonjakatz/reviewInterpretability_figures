# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import matplotlib.pyplot as plt 
sns.set_theme()

import matplotlib
matplotlib.rcParams.update({'font.size': 15})

# %%
data_categories = {'SNPs':"Genomics",
                   'CNV':"Genomics",
                   'CpGs (methylation)':"Epigenetics",
                   'SNV':"Genomics",
                   'mRNA (gene expression)': "Transcriptomics",
                   'miRNA':"Epigenetics",
                   'sc-transcriptomics': "Transcriptomics",
                   'sc-ATAC':"Epigenetics",
                   'proteome': "Proteomics",
                   'clinical': "Clinical",
                   'ncRNA':"Epigenetics",
                   'other': "Other",
                   'WES':"Genomics",
                   'ChIP-seq':"Epigenetics",
                   'WGS':"Genomics",
                   'genotype':"Genomics",
                   "Copy number alterations":"Genomics",
                   "Fusions":"Genomics",
                   "Mutations":"Genomics"}

model_categories = {
    'VAE':"Autoencoder",
    'VNN (dense)':"Visible neural network",
    'AE':"Autoencoder",
    'VAE (conditional)':"Autoencoder",
    'Graph Convolutional Network (GCN)':"Graph neural network",
    'AE (convolutional)':"Autoencoder",
    'LSTM (convolutional)':"Other",
    'ensemble (MAE)':"Other",
    'fuzzy network':"Other",
    'Gaussian-Proces':"Other",
    'PCA-like':"Other",
    'LSTM':'Other',
    'ANN':"Dense neural network",
    'VNN (CNN)':"Visible neural network",
    'AE (vector quantized)':"Autoencoder",
    'AE (stacked)':"Autoencoder",
    'VAE (sparse)':"Autoencoder",
    'Convolutional Neural Network (CNN)':"Convolutional neural network",
    'Dense neural network':"Dense neural network",
    'Transformer':"Transformer",
    'Capsule Network':"Other",
    'Factor Graph Neural Network':"Graph neural network",
    'Self-organising maps (SOM)':"Other",
    'AE (sparse)':"Autoencoder",
    'Graph Network':"Graph neural network",
    'meta-learning':"Other",
    'Generative adversarial network (GAN)':"Other"
}

sns.set_theme(style="whitegrid", font_scale=1.3)

# %%
outPath = "figures"

# %%
pd_table1 = pd.read_csv("data/Table_5.csv")

# %%
pd_Table_1_data_type = pd_table1.copy()
pd_Table_1_data_type = pd.concat([pd_Table_1_data_type, pd_Table_1_data_type['Data type'].str.split(', ', expand=True)], axis=1)
df_merged = pd.concat([pd_Table_1_data_type[0], pd_Table_1_data_type[1], pd_Table_1_data_type[2], pd_Table_1_data_type[3],pd_Table_1_data_type[4],pd_Table_1_data_type[5]], ignore_index=True)

df = pd.DataFrame(df_merged.value_counts())
df = df.loc[list(data_categories.keys()),]
df["cat"] = data_categories.values()

cat_list = []
labels_list = []
for cat in df["cat"].unique():
    cat_list.append(df[df["cat"] == cat][0].astype("int64").tolist())
    labels_list.append(df[df["cat"] == cat].index.tolist())

print(cat_list)
print(labels_list)
# Out:
# [[21, 15, 9, 3, 2, 3, 1, 1, 1], [17, 10, 4, 1, 2], [68, 20], [3], [7], [7]]
# [['SNPs', 'CNV', 'SNV', 'WES', 'WGS', 'genotype', 'Copy number alterations', 'Fusions', 'Mutations'], ['CpGs (methylation)', 'miRNA', 'sc-ATAC', 'ncRNA', 'ChIP-seq'], ['mRNA (gene expression)', 'sc-transcriptomics'], ['proteome'], ['clinical'], ['other']]

# %%
basecol = 150

outer_colors = []
for i, cm in enumerate(["Blues", "Oranges", "Greens", "RdPu", "Purples",'Greys']):
    cmap = plt.colormaps[cm]
    outer_colors.append(cmap(basecol))

    if i == 0:
        inner_colors = cmap(np.linspace(0.4,.9, num=len(cat_list[i])))
    else:
        inner_colors = np.append(inner_colors,  cmap(np.linspace(0.4,.9, num=len(cat_list[i]))), axis=0)

# %%
fig, ax = plt.subplots(figsize=(12,8))

size = 0.3
outervals = list(map(sum, cat_list))
innervals = [j for i in cat_list for j in i]
outer_labels = df["cat"].unique().tolist()
inner_labels = [j for i in labels_list for j in i]

cmap = plt.colormaps["tab20c"]
patches_outer, texts_outer, pct = ax.pie(outervals, radius=1, colors=outer_colors, labels=outer_labels, autopct='%1.0f%%', pctdistance=.85,
       wedgeprops=dict(width=size, edgecolor='w'))
patches_inner, texts_inner = ax.pie(innervals, radius=1-size, colors=inner_colors, #labels=inner_labels, 
       wedgeprops=dict(width=size, edgecolor='w'))

ax.legend(patches_inner, inner_labels, bbox_to_anchor=(1.03, 1.02))
fig.tight_layout()
fig.savefig(os.path.join(outPath, "datatypes_piePlot.png"), dpi=300)

# %%
# !pip install upsetplot
# Out:
# Requirement already satisfied: upsetplot in /Users/drv850/miniconda3/envs/GenNet_38/lib/python3.8/site-packages (0.9.0)
# Requirement already satisfied: pandas>=0.23 in /Users/drv850/miniconda3/envs/GenNet_38/lib/python3.8/site-packages (from upsetplot) (1.5.3)
# Requirement already satisfied: matplotlib>=2.0 in /Users/drv850/miniconda3/envs/GenNet_38/lib/python3.8/site-packages (from upsetplot) (3.7.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/drv850/miniconda3/envs/GenNet_38/lib/python3.8/site-packages (from matplotlib>=2.0->upsetplot) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /Users/drv850/miniconda3/envs/GenNet_38/lib/python3.8/site-packages (from matplotlib>=2.0->upsetplot) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/drv850/miniconda3/envs/GenNet_38/lib/python3.8/site-packages (from matplotlib>=2.0->upsetplot) (4.39.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/drv850/miniconda3/envs/GenNet_38/lib/python3.8/site-packages (from matplotlib>=2.0->upsetplot) (9.4.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/drv850/miniconda3/envs/GenNet_38/lib/python3.8/site-packages (from matplotlib>=2.0->upsetplot) (5.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/drv850/miniconda3/envs/GenNet_38/lib/python3.8/site-packages (from matplotlib>=2.0->upsetplot) (1.0.7)
# Requirement already satisfied: numpy>=1.20 in /Users/drv850/miniconda3/envs/GenNet_38/lib/python3.8/site-packages (from matplotlib>=2.0->upsetplot) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/drv850/miniconda3/envs/GenNet_38/lib/python3.8/site-packages (from matplotlib>=2.0->upsetplot) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/drv850/miniconda3/envs/GenNet_38/lib/python3.8/site-packages (from matplotlib>=2.0->upsetplot) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /Users/drv850/miniconda3/envs/GenNet_38/lib/python3.8/site-packages (from matplotlib>=2.0->upsetplot) (23.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/drv850/miniconda3/envs/GenNet_38/lib/python3.8/site-packages (from pandas>=0.23->upsetplot) (2023.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/drv850/miniconda3/envs/GenNet_38/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib>=2.0->upsetplot) (3.11.0)
# Requirement already satisfied: six>=1.5 in /Users/drv850/miniconda3/envs/GenNet_38/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib>=2.0->upsetplot) (1.16.0)

# %%
#pip install upsetplot!

from upsetplot import UpSet
from upsetplot import from_memberships

# %%
df = pd_table1.copy()
# Splitting the 'Data type' column into separate binary columns
data_types_expanded = df['Data type'].str.get_dummies(sep=', ')  #### changed to ", " instead of ","
df_expanded = pd.concat([df[["Title"]], data_types_expanded], axis=1)
df_expanded = df_expanded.set_index(["Title"])
# df_expanded  = df_expanded.T

df_expanded.to_csv("data/data_types_expanded.csv")

# %%
df_expanded
# Out:
#                                                     CNV  ChIP-seq  \
# Title
# Visualizing population structure with variation...    0         0
# GenNet framework: interpretable deep learning f...    0         0
# Biologically informed deep neural network for p...    1         0
# AIME: Autoencoder-based integrative multi-omics...    0         0
# Biologically informed deep learning to infergen...    0         0
# ...                                                 ...       ...
# Explainable Machine Learning to Identify Patien...    0         0
# Using model explanations to guide deep learning...    0         0
# Interpretable Deep Learning for Improving Cance...    0         0
# Transformer for one stop interpretable cell typ...    0         0
# Structure Primed Embedding on the Transcription...    0         0
#
#                                                     Copy number alterations  \
# Title
# Visualizing population structure with variation...                        0
# GenNet framework: interpretable deep learning f...                        0
# Biologically informed deep neural network for p...                        0
# AIME: Autoencoder-based integrative multi-omics...                        0
# Biologically informed deep learning to infergen...                        0
# ...                                                                     ...
# Explainable Machine Learning to Identify Patien...                        0
# Using model explanations to guide deep learning...                        0
# Interpretable Deep Learning for Improving Cance...                        0
# Transformer for one stop interpretable cell typ...                        0
# Structure Primed Embedding on the Transcription...                        0
#
#                                                     CpGs (methylation)  \
# Title
# Visualizing population structure with variation...                   0
# GenNet framework: interpretable deep learning f...                   0
# Biologically informed deep neural network for p...                   1
# AIME: Autoencoder-based integrative multi-omics...                   0
# Biologically informed deep learning to infergen...                   0
# ...                                                                ...
# Explainable Machine Learning to Identify Patien...                   0
# Using model explanations to guide deep learning...                   0
# Interpretable Deep Learning for Improving Cance...                   0
# Transformer for one stop interpretable cell typ...                   0
# Structure Primed Embedding on the Transcription...                   0
#
#                                                     Fusions  Mutations  SNPs  \
# Title
# Visualizing population structure with variation...        0          0     1
# GenNet framework: interpretable deep learning f...        0          0     1
# Biologically informed deep neural network for p...        1          0     0
# AIME: Autoencoder-based integrative multi-omics...        0          0     0
# Biologically informed deep learning to infergen...        0          0     0
# ...                                                     ...        ...   ...
# Explainable Machine Learning to Identify Patien...        0          0     0
# Using model explanations to guide deep learning...        0          0     0
# Interpretable Deep Learning for Improving Cance...        0          0     0
# Transformer for one stop interpretable cell typ...        0          0     0
# Structure Primed Embedding on the Transcription...        0          0     0
#
#                                                     SNV  WES  WGS  clinical  \
# Title
# Visualizing population structure with variation...    0    0    0         0
# GenNet framework: interpretable deep learning f...    0    1    0         0
# Biologically informed deep neural network for p...    1    0    0         0
# AIME: Autoencoder-based integrative multi-omics...    0    0    0         0
# Biologically informed deep learning to infergen...    0    0    0         0
# ...                                                 ...  ...  ...       ...
# Explainable Machine Learning to Identify Patien...    0    0    0         0
# Using model explanations to guide deep learning...    0    0    0         1
# Interpretable Deep Learning for Improving Cance...    0    0    0         1
# Transformer for one stop interpretable cell typ...    0    0    0         0
# Structure Primed Embedding on the Transcription...    0    0    0         0
#
#                                                     genotype  \
# Title
# Visualizing population structure with variation...         0
# GenNet framework: interpretable deep learning f...         0
# Biologically informed deep neural network for p...         0
# AIME: Autoencoder-based integrative multi-omics...         0
# Biologically informed deep learning to infergen...         0
# ...                                                      ...
# Explainable Machine Learning to Identify Patien...         0
# Using model explanations to guide deep learning...         1
# Interpretable Deep Learning for Improving Cance...         0
# Transformer for one stop interpretable cell typ...         0
# Structure Primed Embedding on the Transcription...         0
#
#                                                     mRNA (gene expression)  \
# Title
# Visualizing population structure with variation...                       0
# GenNet framework: interpretable deep learning f...                       0
# Biologically informed deep neural network for p...                       1
# AIME: Autoencoder-based integrative multi-omics...                       1
# Biologically informed deep learning to infergen...                       0
# ...                                                                    ...
# Explainable Machine Learning to Identify Patien...                       1
# Using model explanations to guide deep learning...                       0
# Interpretable Deep Learning for Improving Cance...                       1
# Transformer for one stop interpretable cell typ...                       1
# Structure Primed Embedding on the Transcription...                       1
#
#                                                     miRNA  ncRNA  other  \
# Title
# Visualizing population structure with variation...      0      0      0
# GenNet framework: interpretable deep learning f...      0      0      0
# Biologically informed deep neural network for p...      0      0      0
# AIME: Autoencoder-based integrative multi-omics...      1      0      0
# Biologically informed deep learning to infergen...      0      0      0
# ...                                                   ...    ...    ...
# Explainable Machine Learning to Identify Patien...      0      0      0
# Using model explanations to guide deep learning...      0      0      0
# Interpretable Deep Learning for Improving Cance...      0      0      0
# Transformer for one stop interpretable cell typ...      0      0      0
# Structure Primed Embedding on the Transcription...      0      0      0
#
#                                                     proteome  sc-ATAC  \
# Title
# Visualizing population structure with variation...         0        0
# GenNet framework: interpretable deep learning f...         0        0
# Biologically informed deep neural network for p...         0        0
# AIME: Autoencoder-based integrative multi-omics...         0        0
# Biologically informed deep learning to infergen...         0        0
# ...                                                      ...      ...
# Explainable Machine Learning to Identify Patien...         0        0
# Using model explanations to guide deep learning...         0        0
# Interpretable Deep Learning for Improving Cance...         0        0
# Transformer for one stop interpretable cell typ...         0        0
# Structure Primed Embedding on the Transcription...         0        1
#
#                                                     sc-transcriptomics
# Title
# Visualizing population structure with variation...                   0
# GenNet framework: interpretable deep learning f...                   0
# Biologically informed deep neural network for p...                   0
# AIME: Autoencoder-based integrative multi-omics...                   0
# Biologically informed deep learning to infergen...                   1
# ...                                                                ...
# Explainable Machine Learning to Identify Patien...                   0
# Using model explanations to guide deep learning...                   0
# Interpretable Deep Learning for Improving Cance...                   0
# Transformer for one stop interpretable cell typ...                   1
# Structure Primed Embedding on the Transcription...                   1
#
# [121 rows x 19 columns]

# %%
combination_counts = df_expanded.groupby(list(df_expanded.columns)).size()
upset = UpSet(combination_counts, subset_size='count', show_counts=True, sort_by='cardinality')
upset.plot()
plt.show()

# %% [markdown]
# # Transciptomics & multi-omcs applications

# %%
df = pd_Table_1_data_type[pd_Table_1_data_type['Data type'].str.contains('mRNA|sc-transcriptomics', na=False)]
print(df.shape)

# For the second part, if you are looking to check if all of the columns 0 to 5 are either "mRNA", "sc-transcriptomics", or NaN, this requires a bit more complex logic:
mask_only = df.apply(lambda row: all(item in ['mRNA (gene expression)', 'sc-transcriptomics', None, np.nan] for item in row[[0, 1, 2, 3, 4, 5]]), axis=1)

# Then you can apply these masks to your DataFrame
df = df[~mask_only]
df
# Out:
# (37, 27)
#                                                   Name  \
# 2    https://www.nature.com/articles/s41586-021-039...
# 3    https://journals.plos.org/ploscompbiol/article...
# 7    https://www.biorxiv.org/content/10.1101/2022.0...
# 9    https://bmcbioinformatics.biomedcentral.com/ar...
# 13   https://www.sciencedirect.com/science/article/...
# 17   https://www.science.org/doi/10.1126/science.aa...
# 21   https://academic.oup.com/bioinformatics/articl...
# 23                    https://arxiv.org/abs/2207.09783
# 30   https://www.frontiersin.org/articles/10.3389/f...
# 39   https://www.biorxiv.org/content/10.1101/2021.1...
# 44   https://academic.oup.com/bioinformatics/articl...
# 47   https://bmcbioinformatics.biomedcentral.com/ar...
# 51   https://bmcmedgenomics.biomedcentral.com/artic...
# 54   https://academic.oup.com/bioinformatics/articl...
# 61   https://www.biorxiv.org/content/10.1101/2021.0...
# 62   https://www.sciencedirect.com/science/article/...
# 64   https://www.biorxiv.org/content/10.1101/2022.0...
# 71        https://ieeexplore.ieee.org/document/4272033
# 72   https://www.biorxiv.org/content/10.1101/2021.0...
# 73           https://pubmed.ncbi.nlm.nih.gov/36217547/
# 80   https://www.sciencedirect.com/science/article/...
# 82   https://genomebiology.biomedcentral.com/articl...
# 83   https://arxiv.org/abs/1912.08937#:~:text=versi...
# 85         https://europepmc.org/article/ppr/ppr415059
# 90           https://pubmed.ncbi.nlm.nih.gov/34890164/
# 91   https://www.nature.com/articles/s42256-021-003...
# 103  https://journals.plos.org/ploscompbiol/article...
# 105  https://www.biorxiv.org/content/10.1101/2022.1...
# 106  https://papers.ssrn.com/sol3/papers.cfm?abstra...
# 108  https://www.biorxiv.org/content/10.1101/2023.0...
# 113  https://academic.oup.com/nargab/article/5/2/lq...
# 115  https://www.sciencedirect.com/science/article/...
# 118  https://www.nature.com/articles/s41598-023-384...
# 120  https://www.biorxiv.org/content/10.1101/2023.0...
#
#                                              Data type Bulk/single cell  \
# 2    CNV, CpGs (methylation), Fusions, SNV, mRNA (g...             Bulk
# 3                        mRNA (gene expression), miRNA             Bulk
# 7      CNV, CpGs (methylation), mRNA (gene expression)             Bulk
# 9    CNV, CpGs (methylation), mRNA (gene expression...             Bulk
# 13                         sc-ATAC, sc-transcriptomics      Single-cell
# 17                        SNPs, mRNA (gene expression)      Single-cell
# 21     CNV, CpGs (methylation), mRNA (gene expression)             Bulk
# 23                       mRNA (gene expression), miRNA             Bulk
# 30               CNV, mRNA (gene expression), proteome             Bulk
# 39          CpGs (methylation), mRNA (gene expression)             Bulk
# 44          CpGs (methylation), mRNA (gene expression)             Bulk
# 47                         CNV, mRNA (gene expression)             Bulk
# 51                    clinical, mRNA (gene expression)             Bulk
# 54                        SNPs, mRNA (gene expression)             Bulk
# 61                           other, sc-transcriptomics      Single-cell
# 62   CNV, CpGs (methylation), SNV, mRNA (gene expre...             Bulk
# 64   CNV, CpGs (methylation), SNV, mRNA (gene expre...             Bulk
# 71                       mRNA (gene expression), miRNA             Bulk
# 72                        SNPs, mRNA (gene expression)             Bulk
# 73                           other, sc-transcriptomics      Single-cell
# 80                    clinical, mRNA (gene expression)             Bulk
# 82                       mRNA (gene expression), other             Bulk
# 83             CNV, SNV, mRNA (gene expression), other             Bulk
# 85                         sc-ATAC, sc-transcriptomics      Single-cell
# 90                       mRNA (gene expression), miRNA             Bulk
# 91   CNV, CpGs (methylation), SNV, mRNA (gene expre...             Bulk
# 103    CNV, CpGs (methylation), mRNA (gene expression)             Bulk
# 105                   CNV, SNV, mRNA (gene expression)             Bulk
# 106                 SNV, mRNA (gene expression), other      Single-cell
# 108              proteome, sc-ATAC, sc-transcriptomics      Single-cell
# 113  CNV, CpGs (methylation), Mutations, clinical, ...             Bulk
# 115  Copy number alterations, CpGs (methylation), m...             Bulk
# 118                   clinical, mRNA (gene expression)             Bulk
# 120  mRNA (gene expression), sc-ATAC, sc-transcript...      Single-cell
#
#                                Which level  \
# 2                    Genes, Pathways, SNPs
# 3                                    miRNA
# 7                           Genes, Protein
# 9                                 Pathways
# 13                            Cells, Genes
# 17   Cell type, Gene sets, Genes, Pathways
# 21                         Genes, Pathways
# 23                                   Genes
# 30                         Genes, Pathways
# 39                         Genes, Pathways
# 44                                   Genes
# 47                                Pathways
# 51                         Genes, Pathways
# 54                                   Genes
# 61                                   Genes
# 62                         Genes, Pathways
# 64                                   Genes
# 71                                   Genes
# 72                         Genes, Pathways
# 73                                   Genes
# 80                                   Genes
# 82                                   Genes
# 83                                   Genes
# 85                               Gene sets
# 90                                   Genes
# 91                                   Genes
# 103                                  Genes
# 105                        Genes, Pathways
# 106                       Gene sets, Genes
# 108             Cell type, Genes, Pathways
# 113                                  Genes
# 115                                  Genes
# 118                     Genes, annotations
# 120                       Gene sets, Genes
#
#                                  Model architecture  \
# 2                                       VNN (dense)
# 3                                                AE
# 7                 Graph Convolutional Network (GCN)
# 9                                                AE
# 13                                              VAE
# 17                                      VNN (dense)
# 21                                        VNN (CNN)
# 23                            AE (vector quantized)
# 30            AE, Graph Convolutional Network (GCN)
# 39                                ANN, VAE (sparse)
# 44                Graph Convolutional Network (GCN)
# 47               Convolutional Neural Network (CNN)
# 51                                              ANN
# 54                                 ANN, VNN (dense)
# 61                                              ANN
# 62                                 ANN, VNN (dense)
# 64                                               AE
# 71                       Self-organising maps (SOM)
# 72                                              ANN
# 73                                              ANN
# 80                Graph Convolutional Network (GCN)
# 82                                          AE, ANN
# 83     Graph Convolutional Network (GCN), VNN (CNN)
# 85            AE, Graph Convolutional Network (GCN)
# 90   Graph Convolutional Network (GCN), Transformer
# 91                Graph Convolutional Network (GCN)
# 103                                             VAE
# 105                                     Transformer
# 106                                     VNN (dense)
# 108                                             VAE
# 113               Graph Convolutional Network (GCN)
# 115                                             VAE
# 118                                         AE, ANN
# 120                                              AE
#
#     Passive vs. Active Approaches         Taxonomy (Table 3. Zhan et al)  \
# 2                 active, passive  attribution, global, hidden semantics
# 3                         passive  attribution, global, hidden semantics
# 7                 active, passive                attribution, semi-local
# 9                         passive                     attribution, local
# 13                        passive   attribution, hidden semantics, local
# 17                         active  attribution, global, hidden semantics
# 21                        passive                     attribution, local
# 23                        passive               global, hidden semantics
# 30                        passive  attribution, global, hidden semantics
# 39                active, passive                     attribution, local
# 44                        passive                    attribution, global
# 47                        passive                     attribution, local
# 51                         active  attribution, global, hidden semantics
# 54                active, passive                attribution, semi-local
# 61                        passive                attribution, semi-local
# 62                         active  attribution, global, hidden semantics
# 64                        passive                attribution, semi-local
# 71                         active               global, hidden semantics
# 72                        passive                                   rule
# 73                        passive                     attribution, local
# 80                         active                     attribution, local
# 82                        passive                attribution, semi-local
# 83                        passive                attribution, semi-local
# 85                        passive                     attribution, local
# 90                active, passive                     attribution, local
# 91                        passive                attribution, semi-local
# 103                       passive   attribution, hidden semantics, local
# 105                       passive             attribution, global, local
# 106                       passive                    attribution, global
# 108                       passive                            attribution
# 113                        active                    attribution, global
# 115                       passive               global, hidden semantics
# 118                        active                hidden semantics, local
# 120                       passive  attribution, global, hidden semantics
#
#                   Post-hoc interpretation method  \
# 2                                       DeepLIFT
# 3                                            NaN
# 7          LRP (Layerwise Relevance Propagation)
# 9                                           SHAP
# 13                                           NaN
# 17                                           NaN
# 21                                       GradCAM
# 23                                           NaN
# 30                                           NaN
# 39                                           NaN
# 44                                  GNNexplainer
# 47                             Other, smoothgrad
# 51                                           NaN
# 54                          Integrated gradients
# 61                          Integrated gradients
# 62                                           NaN
# 64                                           NaN
# 71                                           NaN
# 72                                         Other
# 73                                          SHAP
# 80                                           NaN
# 82                          Integrated gradients
# 83                          Integrated gradients
# 85                                           NaN
# 90                                           NaN
# 91         LRP (Layerwise Relevance Propagation)
# 103                                     DeepSHAP
# 105  LRP (Layerwise Relevance Propagation), SHAP
# 106                                     DeepLIFT
# 108                                        Other
# 113                                          NaN
# 115                                        Other
# 118                                      Weights
# 120                                        Other
#
#                                Interpretation strategy  \
# 2               backpropagation-based, prior knowledge
# 3                                          permutation
# 7    attention, backpropagation-based, prior knowledge
# 9                         game theory, prior knowledge
# 13                                        perturbation
# 17                 connection-weights, prior knowledge
# 21                                     prior knowledge
# 23                                       visualisation
# 30       connection-weights, permutation, perturbation
# 39                              attention, permutation
# 44                              other, prior knowledge
# 47                       perturbation, prior knowledge
# 51                                     prior knowledge
# 54                               backpropagation-based
# 61                               backpropagation-based
# 62          connection-weights, other, prior knowledge
# 64                           connection-weights, other
# 71                                       visualisation
# 72                                other, visualisation
# 73                                         game theory
# 80          connection-weights, other, prior knowledge
# 82                               backpropagation-based
# 83                               backpropagation-based
# 85                                           attention
# 90                                           attention
# 91           backpropagation-based, connection-weights
# 103                 backpropagation-based, game theory
# 105  backpropagation-based, connection-weights, gam...
# 106                              backpropagation-based
# 108                connection-weights, prior knowledge
# 113                                              other
# 115                                          attention
# 118                                 connection-weights
# 120                                 connection-weights
#
#                 Prior knowledge  ...  Year  \
# 2    Gene-annotations, Reactome  ...  2021
# 3                           NaN  ...  2022
# 7                      StringDB  ...  2022
# 9           KEGG, NCI, Reactome  ...  2020
# 13                          NaN  ...  2021
# 17             ENCODE, Own data  ...  2018
# 21                         KEGG  ...  2021
# 23                          NaN  ...  2022
# 30                          NaN  ...  2022
# 39            Hallmark (MSigDB)  ...  2021
# 44                     StringDB  ...  2022
# 47                         KEGG  ...  2021
# 51               KEGG, Reactome  ...  2019
# 54                          NaN  ...  2021
# 61                          NaN  ...  2022
# 62               KEGG, Reactome  ...  2021
# 64                          NaN  ...  2022
# 71                          NaN  ...  2007
# 72                          NaN  ...  2021
# 73                          NaN  ...  2022
# 80                    GeneMania  ...  2021
# 82                          NaN  ...  2022
# 83                          NaN  ...  2020
# 85                          NaN  ...  2021
# 90                     Own data  ...  2022
# 91                          NaN  ...  2021
# 103                         NaN  ...  2023
# 105                  LCPathways  ...  2022
# 106              Gene-Onthology  ...  2023
# 108              Gene-Onthology  ...  2023
# 113                         NaN  ...  2023
# 115                         NaN  ...  2022
# 118              Gene-Onthology  ...  2022
# 120                         NaN  ...  2023
#
#                                                   Task  \
# 2                          classification (supervised)
# 3                            clustering (unsupervised)
# 7                          classification (supervised)
# 9                            clustering (unsupervised)
# 13                           clustering (unsupervised)
# 17                         classification (supervised)
# 21                         classification (supervised)
# 23                           clustering (unsupervised)
# 30                         classification (supervised)
# 39   clustering (unsupervised), regression (supervi...
# 44                         classification (supervised)
# 47                             regression (supervised)
# 51                   regression (supervised), survival
# 54                         classification (supervised)
# 61                         classification (supervised)
# 62   classification (supervised), regression (super...
# 64   classification (supervised), clustering (unsup...
# 71                           clustering (unsupervised)
# 72                         classification (supervised)
# 73                         classification (supervised)
# 80                   regression (supervised), survival
# 82   classification (supervised), clustering (unsup...
# 83   classification (supervised), regression (super...
# 85                           clustering (unsupervised)
# 90                         classification (supervised)
# 91                             regression (supervised)
# 103  classification (supervised), regression (super...
# 105  classification (supervised), regression (super...
# 106                            regression (supervised)
# 108                          clustering (unsupervised)
# 113                        classification (supervised)
# 115                          clustering (unsupervised)
# 118  classification (supervised), regression (super...
# 120                        classification (supervised)
#
#                 Applications to  \
# 2                      Oncology
# 3                      Oncology
# 7                      Oncology
# 9                      Oncology
# 13                        Other
# 17       neurological disorders
# 21                     Oncology
# 23                     Oncology
# 30                     Oncology
# 39                     Oncology
# 44                     Oncology
# 47                     Oncology
# 51                     Oncology
# 54       neurological disorders
# 61                        Other
# 62                     Oncology
# 64                     Oncology
# 71                        Other
# 72                     Oncology
# 73                       traits
# 80                     Oncology
# 82                     Oncology
# 83                     Oncology
# 85             Oncology, immune
# 90                     Oncology
# 91                     Oncology
# 103                    Oncology
# 105  Oncology, drug development
# 106  Oncology, drug development
# 108               covid, immune
# 113                    Oncology
# 115                    Oncology
# 118                    Oncology
# 120              microorganisms
#
#                                                  Notes  \
# 2                                                  NaN
# 3                                                  NaN
# 7                                                  NaN
# 9                                                  NaN
# 13                                                 NaN
# 17   \nimputed genotypes; intermediate phenotype da...
# 21                                                 NaN
# 23                cant find sample size and inputsize
# 30   Interpretation through sensitivity analysis (G...
# 39                                                 NaN
# 44                                                 NaN
# 47                Implementation: iNNvestigate package
# 51                                                 NaN
# 54                                                 NaN
# 61    PATCH-seq: transcriptomics and electrophysiology
# 62                                                 NaN
# 64   “Olden’s approach” - Olden, J.D., Joy, M.K., D...
# 71                                                 NaN
# 72                                                 NaN
# 73                                                 NaN
# 80                                                 NaN
# 82   baseline: median over latent features over sev...
# 83                                                 NaN
# 85                                                 NaN
# 90   weights of the last GTL layer aare used as a m...
# 91                                                 NaN
# 103  Uses a hierarchical autoencoder to combine CNV...
# 105                                                NaN
# 106  Used a sparse layer instead of masking (drugcell)
# 108                                                NaN
# 113                                                NaN
# 115                                                NaN
# 118  node activation value scaled by depth of node ...
# 120                                                NaN
#
#                            0                       1                       2  \
# 2                        CNV      CpGs (methylation)                 Fusions
# 3     mRNA (gene expression)                   miRNA                    None
# 7                        CNV      CpGs (methylation)  mRNA (gene expression)
# 9                        CNV      CpGs (methylation)  mRNA (gene expression)
# 13                   sc-ATAC      sc-transcriptomics                    None
# 17                      SNPs  mRNA (gene expression)                    None
# 21                       CNV      CpGs (methylation)  mRNA (gene expression)
# 23    mRNA (gene expression)                   miRNA                    None
# 30                       CNV  mRNA (gene expression)                proteome
# 39        CpGs (methylation)  mRNA (gene expression)                    None
# 44        CpGs (methylation)  mRNA (gene expression)                    None
# 47                       CNV  mRNA (gene expression)                    None
# 51                  clinical  mRNA (gene expression)                    None
# 54                      SNPs  mRNA (gene expression)                    None
# 61                     other      sc-transcriptomics                    None
# 62                       CNV      CpGs (methylation)                     SNV
# 64                       CNV      CpGs (methylation)                     SNV
# 71    mRNA (gene expression)                   miRNA                    None
# 72                      SNPs  mRNA (gene expression)                    None
# 73                     other      sc-transcriptomics                    None
# 80                  clinical  mRNA (gene expression)                    None
# 82    mRNA (gene expression)                   other                    None
# 83                       CNV                     SNV  mRNA (gene expression)
# 85                   sc-ATAC      sc-transcriptomics                    None
# 90    mRNA (gene expression)                   miRNA                    None
# 91                       CNV      CpGs (methylation)                     SNV
# 103                      CNV      CpGs (methylation)  mRNA (gene expression)
# 105                      CNV                     SNV  mRNA (gene expression)
# 106                      SNV  mRNA (gene expression)                   other
# 108                 proteome                 sc-ATAC      sc-transcriptomics
# 113                      CNV      CpGs (methylation)               Mutations
# 115  Copy number alterations      CpGs (methylation)  mRNA (gene expression)
# 118                 clinical  mRNA (gene expression)                    None
# 120   mRNA (gene expression)                 sc-ATAC      sc-transcriptomics
#
#                           3                       4         5
# 2                       SNV  mRNA (gene expression)      None
# 3                      None                    None      None
# 7                      None                    None      None
# 9                     miRNA                    None      None
# 13                     None                    None      None
# 17                     None                    None      None
# 21                     None                    None      None
# 23                     None                    None      None
# 30                     None                    None      None
# 39                     None                    None      None
# 44                     None                    None      None
# 47                     None                    None      None
# 51                     None                    None      None
# 54                     None                    None      None
# 61                     None                    None      None
# 62   mRNA (gene expression)                    None      None
# 64   mRNA (gene expression)                   miRNA  proteome
# 71                     None                    None      None
# 72                     None                    None      None
# 73                     None                    None      None
# 80                     None                    None      None
# 82                     None                    None      None
# 83                    other                    None      None
# 85                     None                    None      None
# 90                     None                    None      None
# 91   mRNA (gene expression)                    None      None
# 103                    None                    None      None
# 105                    None                    None      None
# 106                    None                    None      None
# 108                    None                    None      None
# 113                clinical  mRNA (gene expression)     miRNA
# 115                   miRNA                    None      None
# 118                    None                    None      None
# 120                    None                    None      None
#
# [34 rows x 27 columns]

# %%
df_merged = pd.concat([pd_Table_1_data_type[0], pd_Table_1_data_type[1], pd_Table_1_data_type[2], pd_Table_1_data_type[3],pd_Table_1_data_type[4],pd_Table_1_data_type[5]], ignore_index=True)

df = pd.DataFrame(df_merged.value_counts())
df
# Out:
#                           0
# mRNA (gene expression)   68
# SNPs                     21
# sc-transcriptomics       20
# CpGs (methylation)       17
# CNV                      15
# miRNA                    10
# SNV                       9
# clinical                  7
# other                     7
# sc-ATAC                   4
# proteome                  3
# genotype                  3
# WES                       3
# WGS                       2
# ChIP-seq                  2
# ncRNA                     1
# Copy number alterations   1
# Fusions                   1
# Mutations                 1
